# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler, Normalizer
from sklearn.decomposition import PCA

# %%
sns.set(style="darkgrid", font="Arial", font_scale=1.5)

# %%
# read in data
raw = pd.read_csv("PCA-KC Data-Assignment.csv").drop("Unnamed: 0", axis=1)
raw
# Out:
#      NBH_ID                        NBH_NAME  total crime  violent crime  \
# 0       177  Country Valley-Hawthorn Square          456            848
# 1        29       East Community Team North          431            980
# 2       221                       The Coves          392             91
# 3       119                      Blue Hills          390           1105
# 4        50                Vineyard Estates          385            304
# ..      ...                             ...          ...            ...
# 194     239                      Ridgefield           89             31
# 195      39                       Riss Lake           70             65
# 196     190                      River View           54             76
# 197       8                  Westside North          122            277
# 198     209                      Winnetonka          122            277
#
#      property crime  Median income  Median home value  \
# 0               358          56044             156425
# 1               332          27803              62380
# 2               687          71767             266200
# 3               262          37498              58311
# 4               401          39375              28200
# ..              ...            ...                ...
# 194              60          82241             183371
# 195             240          49849              99100
# 196             127          56404             139900
# 197              83          50958             210200
# 198              83          73875             115100
#
#      Population with BS or More  White alone  Black or African American alone  \
# 0                           434         1513                              298
# 1                            34          143                              358
# 2                           595         1339                              111
# 3                            91           90                              717
# 4                            86           39                              652
# ..                          ...          ...                              ...
# 194                         421         1143                               85
# 195                         147          582                              525
# 196                         209          615                               62
# 197                         379          525                              148
# 198                         148          929                              133
#
#      ...  Number of Households  Walk Score  Transit Score  Bike Score  \
# 0    ...                   938          15           15.0          25
# 1    ...                   328          47           35.0          33
# 2    ...                   701          31           26.0          28
# 3    ...                   365          50           43.0          36
# 4    ...                   349           6           31.0          30
# ..   ...                   ...         ...            ...         ...
# 194  ...                   506          12           18.0          29
# 195  ...                   570          19           36.0          19
# 196  ...                   419          33           27.0          23
# 197  ...                   542          68           54.0          49
# 198  ...                   471          13           21.0          18
#
#      Population  Animals / Pets  City Facilities  Lights / Signals  \
# 0          1414        1.000000              NaN          7.000000
# 1          3352       13.419753              NaN          3.083333
# 2          3997       12.571429              NaN          2.454545
# 3          5359       17.921348              NaN          2.428571
# 4           739        1.240000              NaN          2.000000
# ..          ...             ...              ...               ...
# 194        4975        1.833333              NaN          2.739130
# 195        2631        9.347826              NaN          5.500000
# 196        1550        2.272727              NaN         14.000000
# 197        1930        5.000000              NaN         11.590909
# 198        1232        1.333333              NaN          3.166667
#
#      Mowing / Weeds  Trash / Recycling
# 0               NaN          12.040000
# 1        125.000000          33.345070
# 2          2.000000           5.770115
# 3         98.133333          38.679842
# 4               NaN          16.750000
# ..              ...                ...
# 194       65.000000          18.304348
# 195       56.000000          52.408163
# 196       41.500000          20.893617
# 197             NaN          14.084507
# 198       17.263158           3.684211
#
# [199 rows x 24 columns]

# %%
raw.columns
# Out:
# Index(['NBH_ID', 'NBH_NAME', 'total crime', 'violent crime', 'property crime',
#        'Median income', 'Median home value', 'Population with BS or More',
#        'White alone', 'Black or African American alone', 'Asian alone',
#        'Hispanic or Latino', 'Total Vacant', 'Total Renter Occupied',
#        'Number of Households', 'Walk Score', 'Transit Score', 'Bike Score',
#        'Population', 'Animals / Pets', 'City Facilities', 'Lights / Signals',
#        'Mowing / Weeds', 'Trash / Recycling'],
#       dtype='object')

# %%
raw.shape
# Out:
# (199, 24)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   NBH_ID                           199 non-null    int64
#  1   NBH_NAME                         199 non-null    object
#  2   total crime                      199 non-null    int64
#  3   violent crime                    199 non-null    int64
#  4   property crime                   199 non-null    int64
#  5   Median income                    199 non-null    int64
#  6   Median home value                199 non-null    int64
#  7   Population with BS or More       199 non-null    int64
#  8   White alone                      199 non-null    int64
#  9   Black or African American alone  199 non-null    int64
#  10  Asian alone                      199 non-null    int64
#  11  Hispanic or Latino               199 non-null    int64
#  12  Total Vacant                     199 non-null    int64
#  13  Total Renter Occupied            199 non-null    int64
#  14  Number of Households             199 non-null    int64
#  15  Walk Score                       199 non-null    int64
#  16  Transit Score                    198 non-null    float64
#  17  Bike Score                       199 non-null    int64
#  18  Population                       199 non-null    int64
#  19  Animals / Pets                   195 non-null    float64
#  20  City Facilities                  8 non-null      float64
#  21  Lights / Signals                 193 non-null    float64
#  22  Mowing / Weeds                   159 non-null    float64
#  23  Trash / Recycling                196 non-null    float64
# dtypes: float64(6), int64(17), object(1)
# memory usage: 37.4+ KB

# %% [markdown]
# City Facilities is ~96% sparse and will have to be dropped.

# %%
Corr = raw.corr()
px.imshow(Corr, width=720, height=720)
# Out:
# <div>                            <div id="4f58989d-120e-43fc-857f-7aa00b11f14a" class="plotly-graph-div" style="height:720px; width:720px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f58989d-120e-43fc-857f-7aa00b11f14a")) {                    Plotly.newPlot(                        "4f58989d-120e-43fc-857f-7aa00b11f14a",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["NBH_ID", "total crime", "violent crime", "property crime", "Median income", "Median home value", "Population with BS or More", "White alone", "Black or African American alone", "Asian alone", "Hispanic or Latino", "Total Vacant", "Total Renter Occupied", "Number of Households", "Walk Score", "Transit Score", "Bike Score", "Population", "Animals / Pets", "City Facilities", "Lights / Signals", "Mowing / Weeds", "Trash / Recycling"], "xaxis": "x", "y": ["NBH_ID", "total crime", "violent crime", "property crime", "Median income", "Median home value", "Population with BS or More", "White alone", "Black or African American alone", "Asian alone", "Hispanic or Latino", "Total Vacant", "Total Renter Occupied", "Number of Households", "Walk Score", "Transit Score", "Bike Score", "Population", "Animals / Pets", "City Facilities", "Lights / Signals", "Mowing / Weeds", "Trash / Recycling"], "yaxis": "y", "z": [[1.0, -0.17811257239461434, -0.18178649708585884, -0.16875448490809192, 0.3008604727788834, 0.09897054121967702, 0.22738769640623946, 0.5399340668805584, -0.1800306078985107, 0.18585676657598854, -0.11509722649794282, -0.425070130918102, -0.13284370957516334, 0.3099778132004905, -0.5777998056528064, -0.7464284935200152, -0.4669780943350822, 0.13676835607526566, -0.1399807046895632, 0.2461810715437224, -0.05931873229544776, -0.2858377247149799, -0.3439202132434302], [-0.17811257239461434, 1.0, 0.7424849389757104, 0.8108977317246648, -0.466835836633266, -0.4061628220789618, -0.42227153720265925, -0.36209799560385536, 0.3029761498595507, -0.2140467403136268, 0.1011796260584292, 0.23611900120076396, 0.08746604419059388, -0.16899013029807797, 0.055731912085070244, 0.11070932474314993, 0.06795007730400089, 0.12579863618193887, 0.10101334020811152, -0.1317130018133812, -0.1055555315187901, 0.1864411528459327, 0.17885850202777115], [-0.18178649708585884, 0.7424849389757104, 1.0, 0.4511506272576142, -0.45483749469253076, -0.38083809532717633, -0.3918852043590833, -0.3611804216406495, 0.34442436323168985, -0.16242319573326927, 0.0752901624215252, 0.3418761040809788, 0.13063096321580417, -0.1307763207651935, 0.08167612732072344, 0.12795478290147, 0.10144499527423513, 0.052989955004863726, 0.1386589155196187, -0.2462983274763662, -0.05059958818033209, 0.21745232995902256, 0.2179643347039024], [-0.16875448490809192, 0.8108977317246648, 0.4511506272576142, 1.0, -0.3517400585175279, -0.3125657028434116, -0.3531852129426673, -0.29135407415970016, 0.19761807615101817, -0.2862589790459152, 0.07397587533868825, 0.1328002426003751, -0.009138534338653822, -0.18674211524664117, -0.024478980855894637, 0.02574148274740511, -0.04738430261790683, 0.05498106885377759, 0.0935856389181429, 0.16924968294115042, -0.10651632847131445, 0.14689298370450776, 0.2051313549645955], [0.3008604727788834, -0.466835836633266, -0.45483749469253076, -0.3517400585175279, 1.0, 0.8254514228133396, 0.6916723288279332, 0.6042701098600114, -0.5419961246711218, 0.09669432599465563, -0.16212619820408236, -0.518379180681714, -0.32699390101134695, 0.1919007647128261, -0.048294907834154785, -0.22846464608906825, -0.020497769756964726, -0.02292953872089454, -0.16370417209390356, 0.1863217573033616, 0.03929912464775288, -0.24814201822056792, -0.44404549397577786], [0.09897054121967702, -0.4061628220789618, -0.38083809532717633, -0.3125 ...

# %%
# Graph the correlation matrix, highlighting coordinate pairs with high Pearson correlation coefficients
highCorr = raw.corr() [abs(raw.corr()) > 0.7]
px.imshow(highCorr, width=720, height=720)
# Out:
# <div>                            <div id="d4070366-f6d6-4891-a37a-c5fe760567c9" class="plotly-graph-div" style="height:720px; width:720px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4070366-f6d6-4891-a37a-c5fe760567c9")) {                    Plotly.newPlot(                        "d4070366-f6d6-4891-a37a-c5fe760567c9",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["NBH_ID", "total crime", "violent crime", "property crime", "Median income", "Median home value", "Population with BS or More", "White alone", "Black or African American alone", "Asian alone", "Hispanic or Latino", "Total Vacant", "Total Renter Occupied", "Number of Households", "Walk Score", "Transit Score", "Bike Score", "Population", "Animals / Pets", "City Facilities", "Lights / Signals", "Mowing / Weeds", "Trash / Recycling"], "xaxis": "x", "y": ["NBH_ID", "total crime", "violent crime", "property crime", "Median income", "Median home value", "Population with BS or More", "White alone", "Black or African American alone", "Asian alone", "Hispanic or Latino", "Total Vacant", "Total Renter Occupied", "Number of Households", "Walk Score", "Transit Score", "Bike Score", "Population", "Animals / Pets", "City Facilities", "Lights / Signals", "Mowing / Weeds", "Trash / Recycling"], "yaxis": "y", "z": [[1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, -0.7464284935200152, null, null, null, null, null, null, null], [null, 1.0, 0.7424849389757104, 0.8108977317246648, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, 0.7424849389757104, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, 0.8108977317246648, null, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, 1.0, 0.8254514228133396, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, 0.8254514228133396, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, 1.0, 0.8358335494789846, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, 0.8358335494789846, 1.0, null, null, null, null, null, 0.7620391715921558, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, 0.7620391715921558, null, null, null, null, null, 1.0, null, null, null, null, null, null, null, null, null], [null, null, null, null, null, null, null, null, null, null, null, null, null, null, 1.0, 0.8030483265241392, 0.851811422657632, null, null, null, null, null, null], [-0.7464284935200152, null, null, null, null, null, null, null, null, null, null, null, null, null, 0.8030483265241392, 1.0, 0.7260746574814126, null, null ...

# %% [markdown]
# **Highly Correlated Variables**

# %%
corr = raw.corr()
print("Total Crime vs. Violet Crime: {:.3f}".format(float(corr["total crime"]["violent crime"])))
print("Total Crime vs. Property Crime: {:.3f}".format(float(corr["total crime"]["property crime"])))
print("Medium Income vs. Medium Home Value: {:.3f}".format(float(corr["Median income"]["Median home value"])))
print("White Alone vs. Population with BS or More: {:.3f}".format(float(corr["White alone"]["Population with BS or More"])))
print("Walk Score vs. Transit Score: {:.3f}".format(float(corr["Walk Score"]["Transit Score"])))
print("Walk Score vs. Bike Score: {:.3f}".format(float(corr["Walk Score"]["Bike Score"])))
print("Bike Score vs. Transit Score: {:.3f}".format(float(corr["Transit Score"]["Bike Score"])))
# Out:
# Total Crime vs. Violet Crime: 0.742
# Total Crime vs. Property Crime: 0.811
# Medium Income vs. Medium Home Value: 0.825
# White Alone vs. Population with BS or More: 0.836
# Walk Score vs. Transit Score: 0.803
# Walk Score vs. Bike Score: 0.852
# Bike Score vs. Transit Score: 0.726

# %% [markdown]
# Regarding the above, our two most highly-correlated variable pairs are:
# * Bike Score and Walk Score
# * White Alone vs. Population with BS or More
#
# Since Bike Score is less correlated with Transit Score than its closely related Walk Score, let's consider dropping this one.
# Regaridng the variables White Alone and Population with BS or More, the progression is less clear. However, since White Alone is not the only race-dependent category, dropping the column Population with BS or More may be more suitable.
#
# In the following, we'll use estiamted cumulative explained variance for normalized versions of the data with and without drops to score a relativly optimized dimensional reduction of the given data. Let
#
# * ${X_0}$ be the null dataset
# * ${X_A}$ be ${X_0}$ with Bike Score, Population, and Population with BS or More dropped from consideration

# %%
sns.histplot(data=raw["Transit Score"], color="blue")
plt.xlabel("")
plt.ylabel("Occurences")
plt.title("Transit Score Distribution")
plt.show()

# %%
sns.histplot(data=raw["Lights / Signals"], color="Orange", kde=True)
plt.xlabel("")
plt.ylabel("Occurences")
plt.title("Lights / Signals Distribution")
plt.show()

# %%
sns.histplot(data=X["Trash / Recycling"], color="Brown", kde=True)
plt.xlabel("")
plt.ylabel("Occurences")
plt.title("Trash Recycling Distribution")
plt.show()

# %% [markdown]
# The above varaibles are not heavily grouped about thier mean, so imputation may not be the best path, or even valid in the case of Mowing / Weeds.

# %%
X0 = raw.loc[:, "total crime": "Trash / Recycling"].drop("City Facilities", axis=1).dropna().values
XA = raw.loc[:, "total crime": "Trash / Recycling"].drop(
    ["Bike Score", "Population with BS or More", "Population", "City Facilities", "Mowing / Weeds"], axis=1).dropna().values

# %%
# Noramlize the data
normalizerA =  MinMaxScaler().fit(X0)
normalizerB = MinMaxScaler().fit(XA)
X0_norm = normalizerA.transform(X0)
XA_norm = normalizerB.transform(XA)
# Fit PCA sets
pcaGenNull = PCA().fit(X0_norm)
pcaGenAlt = PCA().fit(XA_norm)

# %%
Y = pd.DataFrame()
Y["Null ExpVar"] = np.cumsum(pcaGenNull.explained_variance_ratio_)

temp = np.ones(21,)
for i in range(17):
    temp[i] =  np.cumsum(pcaGenAlt.explained_variance_ratio_)[i]
Y["Alt ExpVar"] = temp
Y['newIndex'] = range(1, 22)
Y.set_index("newIndex")
# Out:
#           Null ExpVar  Alt ExpVar
# newIndex
# 1            0.316516    0.289660
# 2            0.474390    0.479012
# 3            0.566887    0.597791
# 4            0.651570    0.686315
# 5            0.718282    0.744671
# 6            0.764550    0.790601
# 7            0.805592    0.828728
# 8            0.838633    0.864626
# 9            0.869260    0.896865
# 10           0.895800    0.925938
# 11           0.920201    0.947748
# 12           0.938764    0.965110
# 13           0.953496    0.979156
# 14           0.965341    0.990182
# 15           0.975180    0.994818
# 16           0.983288    0.998671
# 17           0.989985    1.000000
# 18           0.993827    1.000000
# 19           0.996822    1.000000
# 20           0.999162    1.000000
# 21           1.000000    1.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
fig.suptitle("Cumulaitve Explained Varaince vs. # PCs")

ax1.set_title("w/o Drops")
ax2.set_title("w/ Drops")

ax1.plot(Y["Null ExpVar"][1:], lw=5.0)
ax2.plot(Y["Alt ExpVar"][1:], lw=5.0, color='r')
plt.savefig("graphics/CEV vs PC")

# %% [markdown]
# Based on the above, dropping the columns "Bike Score", "Population", and "Population with BS or More" make **VERY MININIMAL DIFFERENCE** in the dimension reduction's explained varaince.

# %%
plt.figure(figsize=(10, 10))
plt.plot(Y["Alt ExpVar"][1:], lw=5.0)
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Varaince (w/ Drops)")
plt.xlim(0.5, 15.5)
plt.ylim(0.5, 1.05)
plt.savefig("graphics\pcaExpVar1.png")
